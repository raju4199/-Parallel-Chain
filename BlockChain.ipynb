# %%
# %%writefile src/main.cpp
#
# #include <chrono>
# #include <iostream>
# #include <CL/sycl.hpp>
# #include "Blockchain.h"
#
# int main() {
#     auto start_time = std::chrono::high_resolution_clock::now();
#
#     // Select device to perform operations with. We select the default
#     // device using a lambda function as a device selector.
#     cl::sycl::queue q([](cl::sycl::device dev) {
#         return dev.is_gpu() && dev.get_info<cl::sycl::info::device::name>().find("Intel") != std::string::npos;
#     });
#
#     std::cout << "Device: "
#               << q.get_device().get_info<cl::sycl::info::device::name>()
#               << std::endl;
#     {
#         using namespace std;
#         using namespace cl::sycl;
#
#         Blockchain bChain{q};
#
#         std::cout << "Mining block 1..." << std::endl;
#         bChain.AddBlock(q, Block{q, 1, "Block 1 Data"});
#
#         std::cout << "Mining block 2..." << std::endl;
#         bChain.AddBlock(q, Block{q, 2, "Block 2 Data"});
#
#         std::cout << "Mining block 3..." << std::endl;
#         bChain.AddBlock(q, Block{q, 3, "Block 3 Data"});
#     }
#
#     return 0;
# }
# Out:
# Overwriting src/main.cpp

# %% [markdown]
# ### Build and Run
# Select the cell below and click Run ▶ to compile and execute the code above:

# %%
! chmod 755 q; chmod 755 run-chain.sh;if [ -x "$(command -v qsub)" ]; then ./q run-chain.sh; else ./run-chain.sh; fi
# Out:
# Job has been submitted to Intel(R) DevCloud and will execute soon.
#
#  If you do not see result in 60 seconds, please restart the Jupyter kernel:
#  Kernel -> 'Restart Kernel and Clear All Outputs...' and then try again
#
# Job ID                    Name             User            Time Use S Queue
# ------------------------- ---------------- --------------- -------- - -----
# 2262638.v-qsvr-1           ...ub-singleuser u189650         00:00:18 R jupyterhub
# 2262650.v-qsvr-1           run-chain.sh     u189650                0 Q batch
#
# Waiting for Output ██████████ Done⬇
#
# ########################################################################
# #      Date:           Fri 24 Mar 2023 07:41:36 PM PDT
# #    Job ID:           2262650.v-qsvr-1.aidevcloud
# #      User:           u189650
# # Resources:           cput=75:00:00,neednodes=1:gpu:ppn=2,nodes=1:gpu:ppn=2,walltime=06:00:00
# ########################################################################
#
# ## u189650 is compiling DPCPP_Essentials Block Chain
#
# ########################################################################
# # End of output for job 2262650.v-qsvr-1.aidevcloud
# # Date: Fri 24 Mar 2023 07:41:41 PM PDT
# ########################################################################
#
# In file included from src/Blockchain.cpp:1:
# In file included from src/Blockchain.h:6:
# In file included from /glob/development-tools/versions/oneapi/2023.0.1/oneapi/compiler/2023.0.0/linux/bin-llvm/../include/sycl/CL/sycl.hpp:11:
# In file included from /glob/development-tools/versions/oneapi/2023.0.1/oneapi/compiler/2023.0.0/linux/bin-llvm/../include/sycl/sycl.hpp:11:
# In file included from /glob/development-tools/versions/oneapi/2023.0.1/oneapi/compiler/2023.0.0/linux/bin-llvm/../include/sycl/accessor.hpp:11:
# In file included from /glob/development-tools/versions/oneapi/2023.0.1/oneapi/compiler/2023.0.0/linux/bin-llvm/../include/sycl/CL/__spirv/spirv_types.hpp:24:
# /glob/development-tools/versions/oneapi/2023.0.1/oneapi/compiler/2023.0.0/linux/bin-llvm/../include/sycl/detail/defines_elementary.hpp:95:1: error: static assertion failed due to requirement '201103L >= 201703L': DPCPP does not support C++ version earlier than C++17.
# static_assert(__cplusplus >= 201703L,
# ^             ~~~~~~~~~~~~~~~~~~~~~~
# In file included from src/Blockchain.cpp:1:
# In file included from src/Blockchain.h:6:
# In file included from /glob/development-tools/versions/oneapi/2023.0.1/oneapi/compiler/2023.0.0/linux/bin-llvm/../include/sycl/CL/sycl.hpp:11:
# In file included from /glob/development-tools/versions/oneapi/2023.0.1/oneapi/compiler/2023.0.0/linux/bin-llvm/../include/sycl/sycl.hpp:11:
# In file included from /glob/development-tools/versions/oneapi/2023.0.1/oneapi/compiler/2023.0.0/linux/bin-llvm/../include/sycl/accessor.hpp:13:
# /glob/development-tools/versions/oneapi/2023.0.1/oneapi/compiler/2023.0.0/linux/bin-llvm/../include/sycl/buffer.hpp:56:50: error: no template named 'remove_const_t' in namespace 'std'; did you mean simply 'remove_const_t'?
#           typename AllocatorT = buffer_allocator<std::remove_const_t<DataT>>>
#                                                  ^~~~~
# /glob/development-tools/versions/oneapi/2023.0.1/oneapi/compiler/2023.0.0/linux/bin-llvm/../include/sycl/detail/stl_type_traits.hpp:30:1: note: 'remove_const_t' declared here
# using remove_const_t = typename std::remove_const<T>::type;
# ^
# In file included from src/Blockchain.cpp:1:
# In file included from src/Blockchain.h:6:
# In file included from /glob/development-tools/versions/oneapi/2023.0.1/oneapi/compiler/2023.0.0/linux/bin-llvm/../include/sycl/CL/sycl.hpp:11:
# In file included from /glob/development-tools/versions/oneapi/2023.0.1/oneapi/compiler/2023.0.0/linux/bin-llvm/../include/sycl/sycl.hpp:11:
# In file included from /glob/development-tools/versions/oneapi/2023.0.1/oneapi/compiler/2023.0.0/linux/bin-llvm/../include/sycl/accessor.hpp:13:
# /glob/development-tools/versions/oneapi/2023.0.1/oneapi/compiler/2023.0.0/linux/bin-llvm/../include/sycl/buffer.hpp:134:50: error: no template named 'remove_const_t' in namespace 'std'; did you mean 'detail::remove_const_t'?
#           typename AllocatorT = buffer_allocator<std::remove_const_t<T>>,
#                                                  ^~~~~
# /glob/development-tools/versions/oneapi/2023.0.1/oneapi/compiler/2023.0.0/linux/bin-llvm/../include/sycl/detail/stl_type_traits.hpp:30:1: note: 'detail::remove_const_t' declared here
# using remove_const_t = typename std::remove_const<T>::type;
# ^
# In file included from src/Blockchain.cpp:1:
# In file included from src/Blockchain.h:6:
# In file included from /glob/development-tools/versions/oneapi/2023.0.1/oneapi/compiler/2023.0.0/linux/bin-llvm/../include/sycl/CL/sycl.hpp:11:
# In file included from /glob/development-tools/versions/oneapi/2023.0.1/oneapi/compiler/2023.0.0/linux/bin-llvm/../include/sycl/sycl.hpp:11:
# In file included from /glob/development-tools/versions/oneapi/2023.0.1/oneapi/compiler/2023.0.0/linux/bin-llvm/../include/sycl/accessor.hpp:17:
# In file included from /glob/development-tools/versions/oneapi/2023.0.1/oneapi/compiler/2023.0.0/linux/bin-llvm/../include/sycl/detail/generic_type_traits.hpp:16:
# /glob/development-tools/versions/oneapi/2023.0.1/oneapi/compiler/2023.0.0/linux/bin-llvm/../include/sycl/half_type.hpp:121:5: error: statement not allowed in constexpr function
#     do {
#     ^
# /glob/development-tools/versions/oneapi/2023.0.1/oneapi/compiler/2023.0.0/linux/bin-llvm/../include/sycl/half_type.hpp:151:19: error: an explicitly-defaulted copy assignment operator may not have 'const', 'constexpr' or 'volatile' qualifiers
#   constexpr half &operator=(const half &rhs) = default;
#                   ^
# /glob/development-tools/versions/oneapi/2023.0.1/oneapi/compiler/2023.0.0/linux/bin-llvm/../include/sycl/half_type.hpp:156:12: error: binding reference of type 'half' to value of type 'const sycl::detail::host_half_impl::half' drops 'const' qualifier
#     return *this;
#            ^~~~~
# /glob/development-tools/versions/oneapi/2023.0.1/oneapi/compiler/2023.0.0/linux/bin-llvm/../include/sycl/half_type.hpp:161:12: error: binding reference of type 'half' to value of type 'const sycl::detail::host_half_impl::half' drops 'const' qualifier
#     return *this;
#            ^~~~~
# /glob/development-tools/versions/oneapi/2023.0.1/oneapi/compiler/2023.0.0/linux/bin-llvm/../include/sycl/half_type.hpp:166:12: error: binding reference of type 'half' to value of type 'const sycl::detail::host_half_impl::half' drops 'const' qualifier
#     return *this;
#            ^~~~~
# /glob/development-tools/versions/oneapi/2023.0.1/oneapi/compiler/2023.0.0/linux/bin-llvm/../include/sycl/half_type.hpp:171:12: error: binding reference of type 'half' to value of type 'const sycl::detail::host_half_impl::half' drops 'const' qualifier
#     return *this;
#            ^~~~~
# /glob/development-tools/versions/oneapi/2023.0.1/oneapi/compiler/2023.0.0/linux/bin-llvm/../include/sycl/half_type.hpp:177:12: error: binding reference of type 'half' to value of type 'const sycl::detail::host_half_impl::half' drops 'const' qualifier
#     return *this;
#            ^~~~~
# /glob/development-tools/versions/oneapi/2023.0.1/oneapi/compiler/2023.0.0/linux/bin-llvm/../include/sycl/half_type.hpp:188:12: error: binding reference of type 'half' to value of type 'const sycl::detail::host_half_impl::half' drops 'const' qualifier
#     return *this;
#            ^~~~~
# /glob/development-tools/versions/oneapi/2023.0.1/oneapi/compiler/2023.0.0/linux/bin-llvm/../include/sycl/half_type.hpp:199:9: error: cannot assign to non-static data member within const member function 'operator-'
#     Buf ^= 0x8000;
#     ~~~ ^
# /glob/development-tools/versions/oneapi/2023.0.1/oneapi/compiler/2023.0.0/linux/bin-llvm/../include/sycl/half_type.hpp:198:19: note: member function 'sycl::detail::host_half_impl::half::operator-' is declared const here
#   constexpr half &operator-() {
#   ~~~~~~~~~~~~~~~~^~~~~~~~~~~
# /glob/development-tools/versions/oneapi/2023.0.1/oneapi/compiler/2023.0.0/linux/bin-llvm/../include/sycl/half_type.hpp:200:12: error: binding reference of type 'half' to value of type 'const sycl::detail::host_half_impl::half' drops 'const' qualifier
#     return *this;
#            ^~~~~
# /glob/development-tools/versions/oneapi/2023.0.1/oneapi/compiler/2023.0.0/linux/bin-llvm/../include/sycl/half_type.hpp:204:25: error: no return statement in constexpr function
#   __SYCL_CONSTEXPR_HALF operator float() const { return half2Float(Buf); }
#                         ^
# /glob/development-tools/versions/oneapi/2023.0.1/oneapi/compiler/2023.0.0/linux/bin-llvm/../include/sycl/half_type.hpp:282:19: error: an explicitly-defaulted copy assignment operator may not have 'const', 'constexpr' or 'volatile' qualifiers
#   constexpr half &operator=(const half &rhs) = default;
#                   ^
# /glob/development-tools/versions/oneapi/2023.0.1/oneapi/compiler/2023.0.0/linux/bin-llvm/../include/sycl/half_type.hpp:293:10: error: cannot assign to non-static data member within const member function 'operator+='
#     Data += rhs.Data;
#     ~~~~ ^
# /glob/development-tools/versions/oneapi/2023.0.1/oneapi/compiler/2023.0.0/linux/bin-llvm/../include/sycl/half_type.hpp:292:31: note: member function 'sycl::detail::half_impl::half::operator+=' is declared const here
#   __SYCL_CONSTEXPR_HALF half &operator+=(const half &rhs) {
#   ~~~~~~~~~~~~~~~~~~~~~~~~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~~
# /glob/development-tools/versions/oneapi/2023.0.1/oneapi/compiler/2023.0.0/linux/bin-llvm/../include/sycl/half_type.hpp:294:12: error: binding reference of type 'half' to value of type 'const sycl::detail::half_impl::half' drops 'const' qualifier
#     return *this;
#            ^~~~~
# /glob/development-tools/versions/oneapi/2023.0.1/oneapi/compiler/2023.0.0/linux/bin-llvm/../include/sycl/half_type.hpp:298:10: error: cannot assign to non-static data member within const member function 'operator-='
#     Data -= rhs.Data;
#     ~~~~ ^
# /glob/development-tools/versions/oneapi/2023.0.1/oneapi/compiler/2023.0.0/linux/bin-llvm/../include/sycl/half_type.hpp:297:31: note: member function 'sycl::detail::half_impl::half::operator-=' is declared const here
#   __SYCL_CONSTEXPR_HALF half &operator-=(const half &rhs) {
#   ~~~~~~~~~~~~~~~~~~~~~~~~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~~
# /glob/development-tools/versions/oneapi/2023.0.1/oneapi/compiler/2023.0.0/linux/bin-llvm/../include/sycl/half_type.hpp:299:12: error: binding reference of type 'half' to value of type 'const sycl::detail::half_impl::half' drops 'const' qualifier
#     return *this;
#            ^~~~~
# fatal error: too many errors emitted, stopping now [-ferror-limit=]
# 20 errors generated.
# Job Completed in 10 seconds.
